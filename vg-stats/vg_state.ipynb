# %%
import pandas as pd

# %matplotlib inline

import matplotlib.pyplot as plt

# %%
print('hi')
# Out:
# hi

# %%
df= pd.read_csv('vgsales.csv')

df
# Out:
#         Rank                                              Name Platform  \
# 0          1                                        Wii Sports      Wii
# 1          2                                 Super Mario Bros.      NES
# 2          3                                    Mario Kart Wii      Wii
# 3          4                                 Wii Sports Resort      Wii
# 4          5                          Pokemon Red/Pokemon Blue       GB
# ...      ...                                               ...      ...
# 16593  16596                Woody Woodpecker in Crazy Castle 5      GBA
# 16594  16597                     Men in Black II: Alien Escape       GC
# 16595  16598  SCORE International Baja 1000: The Official Game      PS2
# 16596  16599                                        Know How 2       DS
# 16597  16600                                  Spirits & Spells      GBA
#
#          Year         Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ### Which company is the most common video game publisher?

# %%
common_Publisher=df['Publisher'].mode()

# %%
common_Publisher[0]
# Out:
# 'Electronic Arts'

# %% [markdown]
# ### What’s the most common platform?

# %%
common_platform=df['Platform'].mode()
common_platform[0]
# Out:
# 'DS'

# %% [markdown]
# ### What about the most common genre?

# %%
common_genere = df['Genre'].mode()
common_genere[0]
# Out:
# 'Action'

# %% [markdown]
# ### What are the top 20 highest grossing games?

# %%
highe_gross=df.head(20)

# %%
highe_gross['Name']
# Out:
# 0                                       Wii Sports
# 1                                Super Mario Bros.
# 2                                   Mario Kart Wii
# 3                                Wii Sports Resort
# 4                         Pokemon Red/Pokemon Blue
# 5                                           Tetris
# 6                            New Super Mario Bros.
# 7                                         Wii Play
# 8                        New Super Mario Bros. Wii
# 9                                        Duck Hunt
# 10                                      Nintendogs
# 11                                   Mario Kart DS
# 12                     Pokemon Gold/Pokemon Silver
# 13                                         Wii Fit
# 14                                    Wii Fit Plus
# 15                              Kinect Adventures!
# 16                              Grand Theft Auto V
# 17                   Grand Theft Auto: San Andreas
# ...

# %% [markdown]
# ### For North American video game sales, what’s the median?

# %%
NA_median=df['NA_Sales'].median(skipna=None)

# %%
NA_median
# Out:
# 0.08

# %%
dd=df['NA_Sales']

# %%
median = df[df['NA_Sales'] == NA_median]
midd_point = len(median)//2
outcome = median[midd_point-5:midd_point+5]
outcome
# Out:
#         Rank                                Name Platform    Year  \
# 9931    9933            Spider-Man: Edge of Time      3DS  2011.0
# 9934    9936                    Turok: Evolution      GBA  2002.0
# 9957    9959                            Deadpool     XOne  2015.0
# 9996    9998          GT Advance 2: Rally Racing      GBA  2001.0
# 10000  10002                      A Witch's Tale       DS  2009.0
# 10012  10014                   Nickelodeon Dance     X360  2011.0
# 10020  10022            Phantasy Star Collection      GBA  2002.0
# 10022  10024               LEGO Knights' Kingdom      GBA  2004.0
# 10024  10026  Family Game Night 4: The Game Show      PS3  2011.0
# 10026  10028                        NBA Jam 2002      GBA  2002.0
#
#               Genre              Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 9931         Action             Activision      0.08      0.03      0.00
# 9934        Shooter  Acclaim Entertainment      0.08      0.03      0.00
# ...

# %%
# Out:
#         Rank                                               Name Platform  \
# 446      447                                  Dragon Warrior IV      NES
# 497      498        World Soccer Winning Eleven 7 International      PS2
# 1617    1619                             Farming Simulator 2015       PC
# 1926    1928                          Pro Evolution Soccer 2008     X360
# 2067    2069  Winning Eleven: Pro Evolution Soccer 2007 (All...     X360
# ...      ...                                                ...      ...
# 11403  11405            My English Coach: Para Hispanoparlantes       DS
# 11431  11433   Little League World Series Baseball: Double Play       DS
# 11432  11434                               DanceDanceRevolution     X360
# 11455  11457                                         The Hidden      3DS
# 11492  11494                       Ultimate Shooting Collection      Wii
#
#          Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# ...

# %% [markdown]
# ### For the top-selling game of all time, how many standard deviations above/below the mean are its sales for North America?

# %%
top_selling_game=df

# %%
top_game=df.head(1)

# %% [markdown]
# **Using Z score, b-a/(standered deviation of b)**
# <br>
#     a- top selling game
#     <br>
#     b- top game in North America

# %%
b=top_selling_game['NA_Sales'].mean()
a=top_game['NA_Sales']
std=top_selling_game['NA_Sales'].std()
outcom=(a-b)/std
outcom
# Out:
# 0    50.478988
# Name: NA_Sales, dtype: float64

# %% [markdown]
# ### The Nintendo Wii seems to have outdone itself with games. How does its average number of sales compare with all of the other platforms?

# %%
wii_sales = df[(df['Platform']=='Wii')]
not_wii_sales = df[(df['Platform']!='Wii')]
result = (not_wii_sales['Global_Sales'].mean(),
          wii_sales['Global_Sales'].mean())
result
# Out:
# (0.5233896418516336, 0.6994037735849057)
